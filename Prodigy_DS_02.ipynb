# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %% [markdown]
# **Load the Dataset**

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train = pd.read_csv('/kaggle/input/titanic/train.csv')
test = pd.read_csv('/kaggle/input/titanic/test.csv')
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
## statistical info
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
## datatype info
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# **Exploratory Data Analysis**

# %%
## categorical attributes
sns.countplot(x=train['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x=train['Pclass'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x=train['SibSp'])
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
sns.displot(data=train, x='Age', kde = True, hue='Survived')
plt.title("Training set - Histogram plot of Age", fontsize=20, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Training set - Histogram plot of Age')

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
train['Survived'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot(x='Survived',data=train,ax=ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
sns.countplot(x=train['Parch'])
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
sns.countplot(x=train['Embarked'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
## numerical attributes
sns.distplot(x=train['Age'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(train['Fare'])
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %%
#This plot has a comparison of survived passengers depending on the ticket fare and passenger class.
sns.barplot(data=train, x='Pclass', y='Fare', hue='Survived')
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
train[['Sex','Survived']].groupby(['Sex']).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot(x='Sex',hue='Survived',data=train,ax=ax[1])
ax[1].set_title('Sex:Survived vs Dead')
plt.show()

# %%
#Chances for Survival by Port Of Embarkation
sns.catplot(x='Embarked',y='Survived',data=train)
fig=plt.gcf()
fig.set_size_inches(5,3)
plt.show()

# %%
pd.crosstab([train.Embarked,train.Pclass],[train.Sex,train.Survived],margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_50d4e_row0_col0, #T_50d4e_row1_col2 {
#   background-color: #fcfe66;
#   color: #000000;
# }
# #T_50d4e_row0_col1 {
#   background-color: #d2e866;
#   color: #000000;
# }
# #T_50d4e_row0_col2 {
#   background-color: #f2f866;
#   color: #000000;
# }
# #T_50d4e_row0_col3 {
#   background-color: #d8ec66;
#   color: #000000;
# }
# #T_50d4e_row0_col4, #T_50d4e_row2_col3 {
#   background-color: #e8f466;
#   color: #000000;
# }
# #T_50d4e_row1_col0, #T_50d4e_row3_col0, #T_50d4e_row3_col1, #T_50d4e_row3_col2, #T_50d4e_row3_col3, #T_50d4e_row3_col4, #T_50d4e_row4_col0, #T_50d4e_row4_col2, #T_50d4e_row4_col3, #T_50d4e_row4_col4 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_50d4e_row1_col1, #T_50d4e_row6_col0 {
#   background-color: #f9fc66;
#   color: #000000;
# }
# #T_50d4e_row1_col3, #T_50d4e_row1_col4 {
#   background-color: #fbfd66;
#   color: #000000;
# }
# #T_50d4e_row2_col0, #T_50d4e_row5_col1 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_50d4e_row2_col1 {
#   background-color: #f0f866;
#   color: #000000;
# }
# #T_50d4e_row2_col2 {
#   background-color: #eef666;
#   color: #000000;
# }
# #T_50d4e_row2_col4, #T_50d4e_row7_col0 {
#   background-color: #edf666;
#   color: #000000;
# }
# #T_50d4e_row4_col1 {
#   background-color: #fefe66;
#   color: #000000;
# }
# #T_50d4e_row5_col0 {
#   background-color: #e3f166;
#   color: #000000;
# }
# #T_50d4e_row5_col2 {
#   background-color: #ecf666;
#   color: #000000;
# }
# #T_50d4e_row5_col3 {
#   background-color: #f8fc66;
#   color: #000000;
# }
# #T_50d4e_row5_col4 {
#   background-color: #ebf566;
#   color: #000000;
# }
# #T_50d4e_row6_col1 {
#   background-color: #cde666;
#   color: #000000;
# }
# #T_50d4e_row6_col2 {
#   background-color: #e4f266;
#   color: #000000;
# }
# #T_50d4e_row6_col3 {
#   background-color: #bede66;
#   color: #000000;
# }
# #T_50d4e_row6_col4 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_50d4e_row7_col1 {
#   background-color: #bdde66;
#   color: #000000;
# }
# #T_50d4e_row7_col2 {
#   background-color: #d3e966;
#   color: #000000;
# }
# #T_50d4e_row7_col3, #T_50d4e_row8_col1 {
#   background-color: #dcee66;
#   color: #000000;
# }
# #T_50d4e_row7_col4 {
#   background-color: #d1e866;
#   color: #000000;
# }
# #T_50d4e_row8_col0 {
#   background-color: #52a866;
#   color: #f1f1f1;
# }
# #T_50d4e_row8_col2 {
#   background-color: #81c066;
#   color: #000000;
# }
# #T_50d4e_row8_col3 {
#   background-color: #b0d866;
#   color: #000000;
# }
# #T_50d4e_row8_col4 {
#   background-color: #9acc66;
#   color: #000000;
# }
# #T_50d4e_row9_col0, #T_50d4e_row9_col1, #T_50d4e_row9_col2, #T_50d4e_row9_col3, #T_50d4e_row9_col4 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_50d4e">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >Sex</th>
#       <th id="T_50d4e_level0_col0" class="col_heading level0 col0" colspan="2">female</th>
#       <th id="T_50d4e_level0_col2" class="col_heading level0 col2" colspan="2">male</th>
#       <th id="T_50d4e_level0_col4" class="col_heading level0 col4" >All</th>
#     </tr>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level1" >Survived</th>
#       <th id="T_50d4e_level1_col0" class="col_heading level1 col0" >0</th>
#       <th id="T_50d4e_level1_col1" class="col_heading level1 col1" >1</th>
#       <th id="T_50d4e_level1_col2" class="col_heading level1 col2" >0</th>
#       <th id="T_50d4e_level1_col3" class="col_heading level1 col3" >1</th>
#       <th id="T_50d4e_level1_col4" class="col_heading level1 col4" ></th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Embarked</th>
#       <th class="index_name level1" >Pclass</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_50d4e_level0_row0" class="row_heading level0 row0" rowspan="3">C</th>
#       <th id="T_50d4e_level1_row0" class="row_heading level1 row0" >1</th>
#       <td id="T_50d4e_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_50d4e_row0_col1" class="data row0 col1" >42</td>
#       <td id="T_50d4e_row0_col2" class="data row0 col2" >25</td>
#       <td id="T_50d4e_row0_col3" class="data row0 col3" >17</td>
#       <td id="T_50d4e_row0_col4" class="data row0 col4" >85</td>
#     </tr>
#     <tr>
#       <th id="T_50d4e_level1_row1" class="row_heading level1 row1" >2</th>
#       <td id="T_50d4e_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_50d4e_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_50d4e_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_50d4e_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_50d4e_row1_col4" class="data row1 col4" >17</td>
#     </tr>
#     <tr>
#       <th id="T_50d4e_level1_row2" class="row_heading level1 row2" >3</th>
#       <td id="T_50d4e_row2_col0" class="data row2 col0" >8</td>
#       <td id="T_50d4e_row2_col1" class="data row2 col1" >15</td>
#       <td id="T_50d4e_row2_col2" class="data row2 col2" >33</td>
#       <td id="T_50d4e_row2_col3" class="data row2 col3" >10</td>
#       <td id="T_50d4e_row2_col4" class="data row2 col4" >66</td>
#     </tr>
#     <tr>
#       <th id="T_50d4e_level0_row3" class="row_heading level0 row3" rowspan="3">Q</th>
#       <th id="T_50d4e_level1_row3" class="row_heading level1 row3" >1</th>
#       <td id="T_50d4e_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_50d4e_row3_col1" class="data row3 col1" >1</td>
#       <td id="T_50d4e_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_50d4e_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_50d4e_row3_col4" class="data row3 col4" >2</td>
#     </tr>
#     <tr>
#       <th id="T_50d4e_level1_row4" class="row_heading level1 row4" >2</th>
#       <td id="T_50d4e_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_50d4e_row4_col1" class="data row4 col1" >2</td>
#       <td id="T_50d4e_row4_col2" class="data row4 col2" >1</td>
#       <td id="T_50d4e_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_50d4e_row4_col4" class="data row4 col4" >3</td>
#     </tr>
#     <tr>
#       <th id="T_50d4e_level1_row5" class="row_heading level1 row5" >3</th>
#       <td id="T_50d4e_row5_col0" class="data row5 col0" >9</td>
#       <td id="T_50d4e_row5_col1" class="data row5 col1" >24</td>
#       <td id="T_50d4e_row5_col2" class="data row5 col2" >36</td>
#       <td id="T_50d4e_row5_col3" class="data row5 col3" >3</td>
#       <td id="T_50d4e_row5_col4" class="data row5 col4" >72</td>
#     </tr>
#     <tr>
#       <th id="T_50d4e_level0_row6" class="row_heading level0 row6" rowspan="3">S</th>
#       <th id="T_50d4e_level1_row6" class="row_heading level1 row6" >1</th>
#       <td id="T_50d4e_row6_col0" class="data row6 col0" >2</td>
#       <td id="T_50d4e_row6_col1" class="data row6 col1" >46</td>
#       <td id="T_50d4e_row6_col2" class="data row6 col2" >51</td>
#       <td id="T_50d4e_row6_col3" class="data row6 col3" >28</td>
#       <td id="T_50d4e_row6_col4" class="data row6 col4" >127</td>
#     </tr>
#     <tr>
#       <th id="T_50d4e_level1_row7" class="row_heading level1 row7" >2</th>
#       <td id="T_50d4e_row7_col0" class="data row7 col0" >6</td>
#       <td id="T_50d4e_row7_col1" class="data row7 col1" >61</td>
#       <td id="T_50d4e_row7_col2" class="data row7 col2" >82</td>
#       <td id="T_50d4e_row7_col3" class="data row7 col3" >15</td>
#       <td id="T_50d4e_row7_col4" class="data row7 col4" >164</td>
#     </tr>
#     <tr>
#       <th id="T_50d4e_level1_row8" class="row_heading level1 row8" >3</th>
#       <td id="T_50d4e_row8_col0" class="data row8 col0" >55</td>
#       <td id="T_50d4e_row8_col1" class="data row8 col1" >33</td>
#       <td id="T_50d4e_row8_col2" class="data row8 col2" >231</td>
#       <td id="T_50d4e_row8_col3" class="data row8 col3" >34</td>
#       <td id="T_50d4e_row8_col4" class="data row8 col4" >353</td>
#     </tr>
#     <tr>
#       <th id="T_50d4e_level0_row9" class="row_heading level0 row9" >All</th>
#       <th id="T_50d4e_level1_row9" class="row_heading level1 row9" ></th>
#       <td id="T_50d4e_row9_col0" class="data row9 col0" >81</td>
#       <t

# %%
print('Highest Fare was:',train['Fare'].max())
print('Lowest Fare was:',train['Fare'].min())
print('Average Fare was:',train['Fare'].mean())
# Out:
# Highest Fare was: 512.3292
# Lowest Fare was: 0.0
# Average Fare was: 32.204207968574636

# %%
f,ax=plt.subplots(1,3,figsize=(20,8))
sns.distplot(train[train['Pclass']==1].Fare,ax=ax[0])
ax[0].set_title('Fares in Pclass 1')
sns.distplot(train[train['Pclass']==2].Fare,ax=ax[1])
ax[1].set_title('Fares in Pclass 2')
sns.distplot(train[train['Pclass']==3].Fare,ax=ax[2])
ax[2].set_title('Fares in Pclass 3')
plt.show()

# %%
sns.heatmap(train.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->correlation matrix
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()
